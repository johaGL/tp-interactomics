# %%
#works in my case with .venv !
import requests

# %%
import requests
url = "http://www.ebi.ac.uk/Tools/webservices/psicquic/intact/webservices/current/search/query/pubid:17446270"

try:
    httpReq = requests.get(url, proxies=None)
except NameError:
    httpReq = requests.get(url)
ans = httpReq.text

# %%
print(type(ans))
# Out:
# <class 'str'>

# %%
l_l = [ i.replace('uniprotkb:','').split('\t') for i in ans.split('\n') if len(i.split('t')) > 1 ]

# %%
psqData = []
for l in ans.split("\n"):
    if l:
        l = l.split("\t")
        if l[0].startswith("uniprotkb:") and l[1].startswith("uniprotkb:"):
            psqData.append( [ l[0].replace("uniprotkb:", ""),  l[1].replace("uniprotkb:", "") ]  + l[2:] )

# %% [markdown]
# psqData_EBV_EBV = []
# psqData_EBV_Human = []
#
# for x in psqData:
#     if "virus" in x[9] and "virus" in x[10]:
#         psqData_EBV_EBV.append(x)
#     else:
#         psqData_EBV_Human.append(x)
# print(f"{len(psqData_EBV_Human)}  // {len(psqData_EBV_EBV)}")

# %%
print(len(psqData))
# Out:
# 230

# %%
psqData_EBV_EBV = []
psqData_EBV_Human = []

for x in psqData:
    if "virus" in x[9] and "virus" in x[10]:
        psqData_EBV_EBV.append(x)
    else:
        psqData_EBV_Human.append(x)
        
# another option: create set s and add to s psqData[10] and [9] (unique elements)
print(f"{len(psqData_EBV_Human)}  // {len(psqData_EBV_EBV)}")
# Out:
# 171  // 59

# %%
print(psqData_EBV_Human[1][5].split('|')[2].split(':')[1].replace("(display_short)",''))
# Out:
# DBP

# %%
# %matplotlib nbagg
import networkx as nx
import matplotlib.pyplot as plt

plt.figure()
plt.axis('off')


G = nx.Graph()
G.add_edge("a", "b")
G.add_edge("a", "c")
for n in G.nodes:
    print(n)

pos = nx.spring_layout(G)
#print(pos)

nx.draw_networkx_nodes(G, pos, node_color="blue", node_shape="o", nodelist=["a", "b"] )
nx.draw_networkx_nodes(G, pos, node_color="red",  node_shape="o", nodelist=["c"] )
#nx.draw_networkx_labels(G,pos,font_weight=800,font_color='black')
nx.draw_networkx_edges(G, pos, width=0.1)

# Convert names into richer labels and eventually mask some nodes
labelDict = { 
        "a" : "Milou",
        "b" : "Haddock", 
      "c" : "Tryphon"
        }
nx.draw_networkx_labels(G, pos, labelDict, font_size=16, font_color='r')
# Out:
# <img src="data:image/png;base64,..." width="374">
# a
# b
# c
# {'a': Text(0.00036966459238384387, -0.0018927322708898972, 'Milou'),
#  'b': Text(0.1949875592150015, -0.99810726772911, 'Haddock'),
#  'c': Text(-0.19535722380738568, 1.0, 'Tryphon')}

# %%
plt.figure()
plt.axis('off')

P = nx.Graph()

for i in psqData_EBV_EBV:
    P.add_edge(i[0], i[1])
    
for i in psqData_EBV_Human:
    P.add_edge(i[0], i[1])

#THIS CORRESPONDANCES ARE WRONG!!! XML database connection needed to define
nodes_human = set(i[0] for i in psqData_EBV_Human)
nodes_virus = set(i[0] for i in psqData_EBV_EBV )

pos = nx.spring_layout(P)
#print(pos)
nx.draw_networkx_nodes(P, pos, node_color="blue", node_shape="o", node_size = 30, nodelist=list(nodes_human) )
nx.draw_networkx_nodes(P, pos, node_color="red",  node_shape="o", node_size = 30, nodelist=list(nodes_virus) )
nx.draw_networkx_edges(P, pos, width=0.5)

labelDict = {}
for i in nodes_human:
    labelDict[i] = i
for i in nodes_virus:
    labelDict[i] = i
nx.draw_networkx_labels(G, pos, labelDict, font_size=4, font_color='g' )
# Out:
# <img src="data:image/png;base64,..." width="640">
# {'Q3KSU8': Text(0.16052101889064932, -0.1662111538824017, 'Q3KSU8'),
#  'O95967': Text(0.0020063181728262507, -0.33322536404526626, 'O95967'),
#  'P04439': Text(0.23297792911337595, -0.178347543360999, 'P04439'),
#  'P49759': Text(0.20753001209607347, -0.2156107480235756, 'P49759'),
#  'Q9UHV2': Text(0.13158290944081524, 0.35356726473349553, 'Q9UHV2'),
#  'P01857': Text(-0.09500425608373839, 0.3946156824586891, 'P01857'),
#  'P36578': Text(0.2566352189397032, 0.12075674438872482, 'P36578'),
#  'Q5JY77': Text(0.02028528823241926, 0.05977682238063866, 'Q5JY77'),
#  'P03225': Text(0.08928538345908163, 0.1071693416022792, 'P03225'),
#  'P49908': Text(0.08777445313984222, -0.024001924135723607, 'P49908'),
#  'Q9NRD5': Text(0.18215572502626906, -0.07182862817134901, 'Q9NRD5'),
#  'P20700': Text(-0.05824339366271557, 0.10186735410128739, 'P20700'),
#  'P28799': Text(-0.016685174842992045, -0.07485252091350157, 'P28799'),
#  'Q69119': Text(0.07400423009579744, 0.02334303679108828, 'Q69119'),
#  'P04406': Text(0.21869662145370528, -0.23280315888662872, 'P04406'),
#  'Q71U36': Text(-0.3876269214053846, 0.19861132768262485, 'Q71U36'),
#  'Q9NSC5': Text(-0.17965882253536108, 0.05725743845403143, 'Q9NSC5'),
#  'P0C734': Text(0.2269751897121294, 0.7230459522073889, 'P0C734'),
#  'Q3KSU7': Text(0.10202787902393748, 0.2506085039735731, 'Q3KSU7'),
#  'A0A0C7TUY8': Text(0.14153881521307835, 0.4239757384095303, 'A0A0C7TUY8'),
#  'A1L0V1': Text(-0.06724538469250568, 0.029995539145013295, 'A1L0V1'),
#  'Q9Y3Q8': Text(-0.05338184449994971, 0.27277702534555975, 'Q9Y3Q8'),
#  'Q8WXE0': Text(-0.16160090660130977, -0.12513693089217084, 'Q8WXE0'),
#  'P0C731': Text(-0.05992615757737875, 0.3278497861594716, 'P0C731'),
#  'Q9HB63': Text(0.10805087206961757, -0.0597546862998938, 'Q9HB63'),
#  'P03206': Text(0.09110050922969652, 0.15277607257951345, 'P03206'),
#  'Q69139': Text(-0.046296557487695095, 0.016525460492823604, 'Q69139'),
#  'Q9BRK4': Text(0.04501261889954382, -0.11587932660504875, 'Q9BRK4'),
#  'P0CK53': Text(-0.3154194650737831, 0.16371088716440843, 'P0CK53'),
#  'P61289': Text(0.0467582581489628, 0.15811479328565817, 'P61289'),
#  'Q15723': Text(0.1576167318430208, -0.15216157859268645, 'Q15723'),
#  'Q12805': Text(-0.032518918817566626, 0.021901334094495344, 'Q12805'),
#  'P55268': Text(-0.20822166443324852, -0.11534205792516829, 'P55268'),
#  'P03185': Text(-0.10185149682527048, -0.002219246049554368, 'P03185'),
#  'P0C722': Text(0.043934305131304974, -0.06953262579316247, 'P0C722'),
#  'Q69022': Text(-0.0005754248385736405, -0.2468297182360947, 'Q69022'),
#  'P03208': Text(-0.02365089043399672, 0.045326834811074516, 'P03208'),
#  'P12814': Text(0.17460052890819167, 0.46346407040992427, 'P12814'),
#  'Q9Y371': Text(-0.010080306099010948, -0.11306241571433517, 'Q9Y371'),
#  'O95236': Text(0.13608869781656566, 0.1538179899637179, 'O95236'),
#  'P25788': Text(0.06366895935393331, 0.13025554275453835, 'P25788'),
#  'Q96D09': Text(-0.029271997274128932, 0.2778936766062592, 'Q96D09'),
#  'Q8N2S1': Text(-0.015335345547227021, -0.015166376898598862, 'Q8N2S1'),
#  'Q9HA82': Text(0.17562701356010843, -0.24429628491969316, 'Q9HA82'),
#  'P0C762': Text(-0.004136458839307217, -0.12459069279939701, 'P0C762'),
#  'Q3KSQ2': Text(-0.016490841698971165, 0.20510568155037276, 'Q3KSQ2'),
#  'Q16206': Text(0.04855395103661046, 0.20965913137263048, 'Q16206'),
#  'A1KXE4': Text(-0.031136615192040196, -0.1970238555684007, 'A1KXE4'),
#  'Q96BY9': Text(0.19567271250341517, 0.4517619526284384, 'Q96BY9'),
#  'P14618': Text(0.0732441522035717, 0.28488038677807814, 'P14618'),
#  'P0C706': Text(-0.00959666987031775, 0.15728403060885265, 'P0C706'),
#  'O76013': Text(0.03394612704643035, -0.31370803786355084, 'O76013'),
#  'P0C732': Text(0.08068024923871103, 0.1906407838421438, 'P0C732'),
#  'Q3KSV2': Text(0.18156538187043944, 0.1871033463154318, 'Q3KSV2'),
#  'P63279': Text(-0.22703738937588755, -0.06789554983040402, 'P63279'),
#  'Q9BYM8': Text(-0.37016920954445637, 0.22085345997733477, 'Q9BYM8'),
#  'P62995': Text(0.9676043744798616, 0.2971777403376328, 'P62995'),
#  'P0C729': Text(-0.8068854416371307, -0.43302842231285943, 'P0C729'),
#  'Q9NZQ3': Text(-0.017564245979404723, 0.22759742164670746, 'Q9NZQ3'),
#  'Q99816': Text(0.05958760812541401, 0.09978671401662538, 'Q99816'),
#  'Q5SRE7': Text(0.0957736473695727, -0.10671910792595776, 'Q5SRE7'),
#  'Q9UBX5': Text(0.005091483550893783, -0.09409637228026241, 'Q9UBX5'),
#  'O15162': Text(-0.04827629114637855, -0.06973875659813923, 'O15162'),
#  'Q02818': Text(-0.22182459662332593, -0.012606547057873809, 'Q02818'),
#  'Q9HCE6': Text(0.24601123537854316, -0.26029896538059605, 'Q9HCE6'),
#  'Q15942': Text(-0.1115738290596321, 0.03099100469856925, 'Q15942'),
#  'Q69114': Text(-0.023311804791473996, -0.14071393779260766, 'Q69114'),
#  'Q9H8L6': Text(-0.050657059550054326, 0.22741168643225118, 'Q9H8L6'),
#  'Q07021': Text(0.19004979626970794, 0.03511723336878286, 'Q07021'),
#  'Q13164': Text(-0.17813107680219656, -0.46796969618163514, 'Q13164'),
#  'P03224': Text(-0.23552084724968975, 0.1113257268120982, 'P03224'),
#  'P19838': Text(-0.09290371826580608, -0.9490682575806314, 'P19838'),
#  'O43866': Text(0.23731179449413456, 0.215522742372479, 'O43866'),
#  'Q1HVD6': Text(-0.15324338711113064, -0.4007248988571146, 'Q1HVD6'),
#  'P30626': Text(0.25498292553373175, 0.23076981216589204, 'P30626'),
#  'Q8TD31': Text(0.1869292737063086, -0.22801014097965774, 'Q8TD31'),
#  'P0CK47': Text(-0.13683312725330693, -0.05525862536250257, 'P0CK47'),
#  'Q3KST2': Text(0.18512089539965962, 0.0998876951789714, 'Q3KST2'),
#  'Q15326': Text(0.20102489316051117, 0.2553244195475058, 'Q15326'),
#  'P04275': Text(-0.01653054057548662, -0.027887444292952996, 'P04275'),
#  'Q3KSS4': Text(0.115103079864261, 0.026064485055121104, 'Q3KSS4'),
#  'P52292': Text(0.18718590160630663, 0.015444499712646588, 'P52292'),
#  'P53634': Text(-0.15750174882857707, -0.4709120220024932, 'P53634'),
#  'Q9UHF1': Text(-0.19707893650527525, -0.027330664779577338, 'Q9UHF1'),
#  'P0C736': Text(-0.06265235543554508, -0.07372107389989664, 'P0C736'),
#  'Q13077': Text(-0.10869002805343721, -0.13637376804690854, 'Q13077'),
#  'Q3KSU1': Text(0.9203879386134742, 0.2956310772910814, 'Q3KSU1'),
#  'P0C701': Text(0.15837964966897605, 0.393355823564817, 'P0C701'),
#  'O95219': Text(0.11239271610945128, -0.07773734422153149, 'O95219'),
#  'P0CK56': Text(-0.07608387561902821, 0.8868100564270218, 'P0CK56'),
#  'Q3KSS3': Text(-0.22623385883192082, 0.05207198797571137, 'Q3KSS3'),
#  'Q3KSR9': Text(1.0, -0.05657925715661596, 'Q3KSR9'),
#  'A8CSJ8': Text(-0.18062747915233335, 0.005169613871986638, 'A8CSJ8'),
#  'Q3KSP5': Text(-0.02206899717422953, 0.3867654792068378, 'Q3KSP5'),
#  'P0C733': Text(-0.20664969229326235, -0.4402491196459372, 'P0C733'),
#  'Q69131': Text(-0.35922838283852204, -0.8267101198933697, 'Q69131'),
#  'Q3KST1': Text(-0.08236044756517095, -0.27112711879970336, 'Q3KST1'),
#  'Q3KST0': Text(-0.004192850206526564, 0.27624013320580365, 'Q3KST0'),
#  'P68343': Text(-0.7919215696719457, -0.6323189574133132, 'P68343'),
#  'Q3KST5': Text(0.29881643282251963, 0.45992048076683767, 'Q3KST5'),
#  'Q3KSU3': Text(-0.12485215555250262, -0.0006323503252948101, 'Q3KSU3'),
#  'P14348': Text(-0.13345526480885334, -0.02908479884334325, 'P14348'),
#  'P0CK49': Text(0.9603364028576995, -0.05154699850220725, 'P0CK49'),
#  'Q3KSU5': Text(-0.3696918188942056, 0.02838502795364723, 'Q3KSU5'),
#  'P0CK58': Text(-0.4623500936918516, 0.049250161966782384, 'P0CK58'),
#  'P0C6Z4': Text(-0.10897024235709583, 0.00450393266552525, 'P0C6Z4'),
#  'P0C704': Text(-0.2540946473524603, 0.0032587555684476634, 'P0C704'),
#  'P03199': Text(-0.09262374859169828, -0.02586481719565917, 'P03199'),
#  'P03209': Text(-0.01985912689580995, 0.31226559647345903, 'P03209'),
#  'P0CW72': Text(-0.0007893388895224071, -0.055878035886237125, 'P0CW72')}

# %%
# PENDING: ADD GOOD LABELS, CLASSIFY CORRECTLY
